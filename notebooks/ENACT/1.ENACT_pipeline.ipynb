# %%
#ENV: (/scratch/IMMUNEX/pipelines/ENACT/enact-pipeline/enact_env/home/mounim/miniconda3/bin/python3) 
from enact.pipeline import ENACT

# %%
import os
os.getcwd()
# Out:
# '/scratch/Projects/IMMUNEX/notebooks/ENACT'

# %%
from enact.pipeline import ENACT
image = 'IMMUNEX001_Visium_HE_x40_z0.tif'
sample = image[:10]

so_hd = ENACT(
    cache_dir="/scratch/Projects/IMMUNEX/enact_cache",
    wsi_path=f"/scratch/IMMUNEX/PJ2410310_250214/IMAGE/HE_nanozoomer_tif/{image}",
    visiumhd_h5_path=f"/scratch/IMMUNEX/OUTPUT/Visium_NSCLC_{sample}/outs/binned_outputs/square_002um/filtered_feature_bc_matrix.h5",
    tissue_positions_path=f"/scratch/IMMUNEX/OUTPUT/Visium_NSCLC_{sample}/outs/binned_outputs/square_002um/spatial/tissue_positions.parquet",
    cell_typist_model="Human_Colorectal_Cancer",
    analysis_name="IMMUNEX-test", #optional

)
# Out:
# 2025-06-04 08:36:45,768 - ENACT - INFO - <initiate_instance_variables> ENACT running with the following configurations:
#  analysis_name: IMMUNEX-test
#  run_synthetic: False
#  cache_dir: /scratch/Projects/IMMUNEX/enact_cache
#  wsi_path: /scratch/IMMUNEX/PJ2410310_250214/IMAGE/HE_nanozoomer_tif/IMMUNEX001_Visium_HE_x40_z0.tif
#  visiumhd_h5_path: /scratch/IMMUNEX/OUTPUT/Visium_NSCLC_IMMUNEX001/outs/binned_outputs/square_002um/filtered_feature_bc_matrix.h5
#  tissue_positions_path: /scratch/IMMUNEX/OUTPUT/Visium_NSCLC_IMMUNEX001/outs/binned_outputs/square_002um/spatial/tissue_positions.parquet
#  segmentation: True
#  bin_to_geodataframes: True
#  bin_to_cell_assignment: True
#  cell_type_annotation: True
#  seg_method: stardist
#  image_type: he
#  nucleus_expansion: True
#  expand_by_nbins: 2
#  patch_size: 4000
#  bin_representation: polygon
#  bin_to_cell_method: weighted_by_cluster
#  cell_annotation_method: celltypist
#  cell_typist_model: Human_Colorectal_Cancer
#  use_hvg: True
#  n_hvg: 1000
#  destripe_norm: False
#  n_clusters: 4
#  n_pcs: 250
#  chunks_to_run: []
#  block_size: 4096
#  prob_thresh: 0.005
#  overlap_thresh: 0.001
#  min_overlap: 28
#  context: 128
#  n_tiles: (4, 4, 1)
#  stardist_modelname: 2D_versatile_he
#  channel_to_segment: 2
#  cell_markers: {}

# %%
so_hd.run_enact()
# Out:
# 2025-06-04 12:02:51,350 - ENACT - INFO - <load_image> Successfully loaded image!
# <load_image> Successfully loaded image!
# 2025-06-04 12:03:03,673 - ENACT - INFO - <run_enact> Expanding nuclei to get cell boundaries
# <run_enact> Expanding nuclei to get cell boundaries
# Mean cell area: 454.53043770134116
# 2025-06-04 12:03:04,582 - ENACT - INFO - <get_bin_size> Bin size computed: 8.745013174178894 pixels
# <get_bin_size> Bin size computed: 8.745013174178894 pixels
# 2025-06-04 12:04:18,789 - ENACT - INFO - <expand_nuclei_with_voronoi> Number of unexpanded cells: 33
# <expand_nuclei_with_voronoi> Number of unexpanded cells: 33
# 2025-06-04 12:04:19,370 - ENACT - INFO - <convert_stardist_output_to_gdf> Mean nuclei area after expansion: 1386.404279195347
# <convert_stardist_output_to_gdf> Mean nuclei area after expansion: 1386.404279195347
# 2025-06-04 12:05:10,697 - ENACT - INFO - <split_df_to_chunks> Splitting into chunks. output_dir: /scratch/Projects/IMMUNEX/enact_cache/IMMUNEX-test/chunks/cells_gdf
# <split_df_to_chunks> Splitting into chunks. output_dir: /scratch/Projects/IMMUNEX/enact_cache/IMMUNEX-test/chunks/cells_gdf
# 100%|██████████████████████████████████████████████████████████████████████| 64/64 [00:14<00:00,  4.53it/s]
# 2025-06-04 12:05:56,299 - ENACT - INFO - <load_visiumhd_dataset> Missing the following markers: set()
# <load_visiumhd_dataset> Missing the following markers: set()
# 2025-06-04 12:05:57,112 - ENACT - INFO - <generate_bin_polys> Generating bin polygons. num_bins: 10822530
# <generate_bin_polys> Generating bin polygons. num_bins: 10822530
# 100%|███████████████████████████████████████████████████████| 10822530/10822530 [02:14<00:00, 80545.91it/s]
# 2025-06-04 12:08:23,229 - ENACT - INFO - <split_df_to_chunks> Splitting into chunks. output_dir: /scratch/Projects/IMMUNEX/enact_cache/IMMUNEX-test/chunks/bins_gdf
# <split_df_to_chunks> Splitting into chunks. output_dir: /scratch/Projects/IMMUNEX/enact_cache/IMMUNEX-test/chunks/bins_gdf
# 100%|██████████████████████████████████████████████████████████████████████| 64/64 [03:04<00:00,  2.89s/it]
# 2025-06-04 12:11:57,708 - ENACT - INFO - <load_visiumhd_dataset> Missing the following markers: set()
# <load_visiumhd_dataset> Missing the following markers: set()
# 2025-06-04 12:11:58,357 - ENACT - INFO - <assign_bins_to_cells> Assigning bins to cells using weighted_by_cluster method
# <assign_bins_to_cells> Assigning bins to cells using weighted_by_cluster method
# 100%|██████████████████████████████████████████████████████████████████| 64/64 [00:00<00:00, 120971.36it/s]
# 2025-06-04 12:11:58,360 - ENACT - INFO - <assign_bins_to_cells> Successfully assigned bins to cells!
# <assign_bins_to_cells> Successfully assigned bins to cells!
# 2025-06-04 12:11:58,362 - ENACT - INFO - <initiate_instance_variables> ENACT running with the following configurations:
#  analysis_name: IMMUNEX-test
#  run_synthetic: False
#  cache_dir: /scratch/Projects/IMMUNEX/enact_cache
#  wsi_path: /scratch/IMMUNEX/PJ2410310_250214/IMAGE/HE_nanozoomer_tif/IMMUNEX001_Visium_HE_x40_z0.tif
#  visiumhd_h5_path: /scratch/IMMUNEX/OUTPUT/Visium_NSCLC_IMMUNEX001/outs/binned_outputs/square_002um/filtered_feature_bc_matrix.h5
#  tissue_positions_path: /scratch/IMMUNEX/OUTPUT/Visium_NSCLC_IMMUNEX001/outs/binned_outputs/square_002um/spatial/tissue_positions.parquet
#  segmentation: True
#  bin_to_geodataframes: True
#  bin_to_cell_assignment: True
#  cell_type_annotation: True
#  seg_method: stardist
#  image_type: he
#  nucleus_expansion: True
#  expand_by_nbins: 2
#  patch_size: 4000
#  bin_representation: polygon
#  bin_to_cell_method: weighted_by_cluster
#  cell_annotation_method: celltypist
#  cell_typist_model: Human_Colorectal_Cancer
#  use_hvg: True
#  n_hvg: 1000
#  destripe_norm: False
#  n_clusters: 4
#  n_pcs: 250
#  chunks_to_run: []
#  block_size: 4096
#  prob_thresh: 0.005
#  overlap_thresh: 0.001
#  min_overlap: 28
#  context: 128
#  n_tiles: (4, 4, 1)
#  stardist_modelname: 2D_versatile_he
#  channel_to_segment: 2
#  cell_markers: {}
#
# <initiate_instance_variables> ENACT running with the following configurations:
#  analysis_name: IMMUNEX-test
#  run_synthetic: False
#  cache_dir: /scratch/Projects/IMMUNEX/enact_cache
#  wsi_path: /scratch/IMMUNEX/PJ2410310_250214/IMAGE/HE_nanozoomer_tif/IMMUNEX001_Visium_HE_x40_z0.tif
#  visiumhd_h5_path: /scratch/IMMUNEX/OUTPUT/Visium_NSCLC_IMMUNEX001/outs/binned_outputs/square_002um/filtered_feature_bc_matrix.h5
#  tissue_positions_path: /scratch/IMMUNEX/OUTPUT/Visium_NSCLC_IMMUNEX001/outs/binned_outputs/square_002um/spatial/tissue_positions.parquet
#  segmentation: True
#  bin_to_geodataframes: True
#  bin_to_cell_assignment: True
#  cell_type_annotation: True
#  seg_method: stardist
#  image_type: he
#  nucleus_expansion: True
#  expand_by_nbins: 2
#  patch_size: 4000
#  bin_representation: polygon
#  bin_to_cell_method: weighted_by_cluster
#  cell_annotation_method: celltypist
#  cell_typist_model: Human_Colorectal_Cancer
#  use_hvg: True
#  n_hvg: 1000
#  destripe_norm: False
#  n_clusters: 4
#  n_pcs: 250
#  chunks_to_run: []
#  block_size: 4096
#  prob_thresh: 0.005
#  overlap_thresh: 0.001
#  min_overlap: 28
#  context: 128
#  n_tiles: (4, 4, 1)
#  stardist_modelname: 2D_versatile_he
#  channel_to_segment: 2
#  cell_markers: {}
#
# 📂 Storing models in /home/mounim/.celltypist/data/models
# 💾 Total models to download: 1
# ⏩ Skipping [1/1]: Human_Colorectal_Cancer.pkl (file exists)
# 🔬 Input data has 462327 cells and 1000 genes
# 🔗 Matching reference genes in the model
# 🧬 156 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 2025-06-04 12:12:17,264 - ENACT - INFO - <run_cell_type_annotation> Successfully ran CellTypist on Data.
# <run_cell_type_annotation> Successfully ran CellTypist on Data.
# 2025-06-04 12:12:17,266 - ENACT - INFO - <initiate_instance_variables> ENACT running with the following configurations:
#  analysis_name: IMMUNEX-test
#  run_synthetic: False
#  cache_dir: /scratch/Projects/IMMUNEX/enact_cache
#  wsi_path: /scratch/IMMUNEX/PJ2410310_250214/IMAGE/HE_nanozoomer_tif/IMMUNEX001_Visium_HE_x40_z0.tif
#  visiumhd_h5_path: /scratch/IMMUNEX/OUTPUT/Visium_NSCLC_IMMUNEX001/outs/binned_outputs/square_002um/filtered_feature_bc_matrix.h5
#  tissue_positions_path: /scratch/IMMUNEX/OUTPUT/Visium_NSCLC_IMMUNEX001/outs/binned_outputs/square_002um/spatial/tissue_positions.parquet
#  segmentation: True
#  bin_to_geodataframes: True
#  bin_to_cell_assignment: True
#  cell_type_annotation: True
#  seg_method: stardist
#  image_type: he
#  nucleus_expansion: True
#  expand_by_nbins: 2
#  patch_size: 4000
#  bin_representation: polygon
#  bin_to_cell_method: weighted_by_cluster
#  cell_annotation_method: celltypist
#  cell_typist_model: Human_Colorectal_Cancer
#  use_hvg: True
#  n_hvg: 1000
#  destripe_norm: False
#  n_clusters: 4
#  n_pcs: 250
#  chunks_to_run: []
#  block_size: 4096
#  prob_thresh: 0.005
#  overlap_thresh: 0.001
#  min_overlap: 28
#  context: 128
#  n_tiles: (4, 4, 1)
#  stardist_modelname: 2D_versatile_he
#  channel_to_segment: 2
#  cell_markers: {}
#
# <initiate_instance_variables> ENACT running with the following configurations:
#  analysis_name: IMMUNEX-test
#  run_synthetic: False
#  cache_dir: /scratch/Projects/IMMUNEX/enact_cache
#  wsi_path: /scratch/IMMUNEX/PJ2410310_250214/IMAGE/HE_nanozoomer_tif/IMMUNEX001_Visium_HE_x40_z0.tif
#  visiumhd_h5_path: /scratch/IMMUNEX/OUTPUT/Visium_NSCLC_IMMUNEX001/outs/binned_outputs/square_002um/filtered_feature_bc_matrix.h5
#  tissue_positions_path: /scratch/IMMUNEX/OUTPUT/Visium_NSCLC_IMMUNEX001/outs/binned_outputs/square_002um/spatial/tissue_positions.parquet
#  segmentation: True
#  bin_to_geodataframes: True
#  bin_to_cell_assignment: True
#  cell_type_annotation: True
#  seg_method: stardist
#  image_type: he
#  nucleus_expansion: True
#  expand_by_nbins: 2
#  patch_size: 4000
#  bin_representation: polygon
#  bin_to_cell_method: weighted_by_cluster
#  cell_annotation_method: celltypist
#  cell_typist_model: Human_Colorectal_Cancer
#  use_hvg: True
#  n_hvg: 1000
#  destripe_norm: False
#  n_clusters: 4
#  n_pcs: 250
#  chunks_to_run: []
#  block_size: 4096
#  prob_thresh: 0.005
#  overlap_thresh: 0.001
#  min_overlap: 28
#  context: 128
#  n_tiles: (4, 4, 1)
#  stardist_modelname: 2D_versatile_he
#  channel_to_segment: 2
#  cell_markers: {}
#
# ... storing 'patch_id' as categorical
# 2025-06-04 12:13:00,386 - ENACT - INFO - <load_image> Successfully loaded image!
# <load_image> Successfully loaded image!
# 2025-06-04 12:13:14,858 - ENACT - INFO - <package_results> Packaged CellTypist results
# <package_results> Packaged CellTypist results
#             Sample ready to visualize on TissUUmaps. To install TissUUmaps, follow the instructions at:
#
#             https://tissuumaps.github.io/TissUUmaps-docs/docs/intro/installation.html#.
#
#             To view the the sample, follow the instructions at:
#
#             https://tissuumaps.github.io/TissUUmaps-docs/docs/starting/projects.html#loading-projects
#
#             TissUUmaps project file is located here:
#
#             /scratch/Projects/IMMUNEX/enact_cache/IMMUNEX-test/tmap/weighted_by_cluster|celltypist_tmap.tmap

# %%
0
